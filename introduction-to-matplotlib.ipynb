# %%
# the magic command allows all plots to show within jupyter notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
a = plt.plot([1,2,3,4]);

# %%
plt.plot([1,2,3,4],[7,8,9,10]);

# %%
#method 1 pyplot 
g = plt.figure()
ax = g.add_axes()
plt.plot([1,2,3,4],[7,8,9,10])
plt.show();

# %%
#mehod 2 object oriented.(recommended)
fig,ax = plt.subplots()
x=[1,2,3,4]
y=[9,8,7,6]
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [10,8,7,6,5]

fig,ax = plt.subplots()
ax.plot(x,y)
ax.set(xlabel="X axis",ylabel="Y axis",title="Figure")
fig.savefig("Example.png")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#use of linspace to divide a range in equal intervals
x = np.linspace(0,100,100)
y = np.linspace(1,10,100)

# %%
fig,ax = plt.subplots()
ax.plot(x,x**2);

# %%
#scatter plot
fig,ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %%
#bar diagram
a = {"Cow":8,"Dog":12,"Goat":15,"Cat":2}
fig,ax = plt.subplots()
ax.bar(a.keys(),a.values(),)
ax.set(xlabel="Animals",ylabel="No. of animals",title="Bar Diagram");

# %%
#histogram
fig, ax = plt.subplots()
ax.hist(np.random.randn(1000));

# %%
# how to create multiple axes where each tuple counts as a row and elements in tuple as columns
fig,((ax1,ax2),(ax3,ax4),(ax5,ax6))= plt.subplots(3,2,True,True)
ax1.plot(x,y);

# %%
# create pyplot from series and use cumilitive sum or `cumsum()` funcion
# also using `pd.date_range` to create dates
s = pd.Series(np.random.rand(1000),index=pd.date_range("1,1,2020",periods=1000))
s=s.cumsum()
s.plot()

# %%
cs = pd.read_csv("data/car-sales.csv")
cs['Price'] = cs['Price'].str.replace('[\$\,]','').astype(float)
cs['Price'] = cs['Price'].astype(int)
cs.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500

# %%
cs['Sale Date'] = pd.date_range('1/1/2019','1/1/2020',len(cs))
cs.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price           Sale Date
# 0  Toyota  White         150043      4   4000 2019-01-01 00:00:00
# 1   Honda    Red          87899      4   5000 2019-02-10 13:20:00
# 2  Toyota   Blue          32549      3   7000 2019-03-23 02:40:00
# 3     BMW  Black          11179      5  22000 2019-05-02 16:00:00
# 4  Nissan  White         213095      4   3500 2019-06-12 05:20:00

# %%
cs['Total Sales'] = cs['Price'].cumsum()
cs.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price           Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2019-01-01 00:00:00         4000
# 1   Honda    Red          87899      4   5000 2019-02-10 13:20:00         9000
# 2  Toyota   Blue          32549      3   7000 2019-03-23 02:40:00        16000
# 3     BMW  Black          11179      5  22000 2019-05-02 16:00:00        38000
# 4  Nissan  White         213095      4   3500 2019-06-12 05:20:00        41500

# %%
cs['Total Sales'].plot();

# %%
cs.plot(x='Sale Date',y='Price',kind='scatter');

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0  0.717205  0.880873  0.216862  0.928154
# 1  0.440450  0.710311  0.358380  0.185415
# 2  0.939656  0.247643  0.756869  0.029905
# 3  0.207960  0.660474  0.047639  0.178278
# 4  0.387139  0.155516  0.303449  0.517340

# %%
#option 1 for bar
df.plot.bar();

# %%
#option 2 for bar
df.plot(kind='bar');

# %%
cs.plot(x='Make',y="Odometer (KM)",kind='bar');

# %%
#option 1 for hist
cs['Odometer (KM)'].plot.hist();

# %%
#option 2 for hist
cs['Odometer (KM)'].plot(kind='hist');

# %%
#option 3 for hist
cs['Odometer (KM)'].hist();

# %%
hd = pd.read_csv("data/heart-disease.csv")
hd.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
hd['age'].plot.hist();

# %%
#overlapping plot...all in one figure
hd.plot.hist();

# %%
#subplots happen but x & y axis of all columns is same making it difficult to observe some observations!
hd.plot.hist(subplots=True,figsize=(5,50));

# %%
# best one..each has separate axis and the spread of data of each column is visible clearly 
# as each column has different values in x axis & y axis
hd.hist(figsize=(9,10));

# %%
#create an array of 10 random floats between 0 to 9
a = np.random.uniform(1,10,10)
#create an array of 10 random integers between 0 to 9
b = np.random.randint(1,10,10)
a,b
# Out:
# (array([8.13650479, 5.78436794, 9.06271707, 6.72917033, 7.49492338,
#         1.36618382, 4.22513099, 8.25868209, 2.37320984, 7.65626912]),
#  array([1, 1, 5, 7, 5, 1, 4, 8, 2, 6]))

# %%
hs = pd.read_csv("data/heart-disease.csv")
hs = hs[hs['age']>50]
hs.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#pyplot method of scatter plot of age vs cholesterol with target as
#color indicator whether the patient has cancer or not
hs.plot(x='age',y='chol',c='target',kind='scatter');

# %%
#object oriented method mixed with pyplot 
#scatter plot of age vs cholesterol with target as 
#color plot indicator whether the patient has cancer or not
#see matplotlib plot function's documentation for more customizations
fig,ax = plt.subplots();
hs.plot(x='age',y='chol',c='target',kind='scatter',figsize=(8,8),ax=ax);

# %%
#object oriented method from scratch
fig,ax = plt.subplots();
scatter = ax.scatter(x=hs['age'],y=hs['chol'],c=hs['target']);

#can also use the method below to only mention col names by using
#data parameter where data = obj name (here hs) of the dataframe/csv 
#scatter = ax.scatter(x='age',y='chol',c='target',data=hs);

#sets the x,y and title labels
ax.set(xlabel='age',ylabel='chol',title="Heart Disease & Cholesterol Levels");

#shows the legend by selecting all legend elements from scatter
ax.legend(*scatter.legend_elements(),title='Target');

#displays the mean across the axis
ax.axhline(hs['chol'].mean(),ls='--');

# %%
# subplots of age vs chol & heartrate
fig,(ax1,ax2) = plt.subplots(nrows=2,sharex=True,figsize=(10,10))

scatter1 = ax1.scatter(x="age",y="chol",c="target",data=hs)
scatter2 = ax2.scatter(x=hs["age"],y=hs["thalach"],c=hs["target"])

ax1.set(ylabel="chol",title="Cholesterol Levels by Age")
ax2.set(xlabel='age',ylabel='thalach',title="Max Heart Rates by Age")

ax1.legend(*scatter1.legend_elements(),title='Target')
ax2.legend(*scatter2.legend_elements(),title='Target')

ax1.axhline(y=hs["chol"].mean(),ls='--')
ax2.axhline(y=hs['thalach'].mean(),ls='--');

fig.suptitle("Heart Disease",fontsize='16',fontweight='bold');

# %% [markdown]
# ## Customising plots with different stylings

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-darkgrid")

# %%
hs.plot.hist(figsize=(5,5));

# %%
x = np.random.rand(10,3)
df = pd.DataFrame(x,columns=['a','b','c'])
ax = df.plot(kind='bar');
ax.set(title='random number graph',xlabel='row number',ylabel='random number');
ax.legend().set_visible(True)

# %% [markdown]
# ## The Final Plot

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

hs = pd.read_csv('data/heart-disease.csv')
hs = hs[hs['age']>50]

# %%
plt.style.use("dark_background")

fig, (ax1,ax2) = plt.subplots(nrows=2,ncols=1,sharex=True,figsize=(10,10))

scatter1 = ax1.scatter(x='age',y='chol',data=hs,c='target',cmap='winter')
scatter2 = ax2.scatter(x='age',y='thalach',data=hs,c='target',cmap='winter')

ax1.set_xlim([50,80])
ax1.set_ylim([100,600])

ax1.set(ylabel='Cholesterol',title='Cholesterol Levels by Age')
ax2.set(xlabel='Age',ylabel='Max Heart Rate',title='Max Heart Rates by Age',ylim=[60,200]);

ax1.legend(*scatter1.legend_elements(),title="Target")
ax2.legend(*scatter2.legend_elements(),title="Target")

ax1.axhline(hs['chol'].mean(),ls='--',color='r',label='Average')
ax2.axhline(hs['thalach'].mean(),ls='--',color='r',label='Average');

fig.suptitle("Heart Disease",fontsize='16',fontweight='bold');

# %% [markdown]
# Saving Image
# Two ways: 1.Right click image and save as.
#           2.The code below

# %%
#saves the images as png
fig.savefig("heartdisease.png")
